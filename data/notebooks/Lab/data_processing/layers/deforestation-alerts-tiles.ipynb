# %% [markdown]
# # Create layer for deforestation alerts
#
# This notebook generates a point layer from the deforestation alerts table in BigQuery, ready to be uploaded to Mapbox.
#
# Steps:
#
# - 1. Download the latest table from [BigQuery (deforestation-alerts/alerts)](https://console.cloud.google.com/bigquery?referrer=search&project=mangrove-atlas-246414&ws=!1m9!1m3!3m2!1smangrove-atlas-246414!2sdeforestation_alerts!1m4!4m3!1smangrove-atlas-246414!2sdeforestation_alerts!3salerts&pli=1): export the table to a GCS location and download as CSV.
# - 2. Load the CSV into a GeoDataFrame using the lat and lon columns.
# - 3. Convert the GeoDataFrame to MBTiles, adding a priority score so that recent alerts are retained preferentially when Tippecanoe drops features at low zoom levels. This ensures that all recent alerts remain visible, while older points may be simplified or omitted to reduce tile size.

# %% [markdown]
# ### Set up

# %%
import pandas as pd
import geopandas as gpd
import json
from datetime import date, datetime

# %%
CURRENT_DATE = date.today()
INPUT = "alerts_data.geojson"
OUTPUT = "alerts_preprocessed.geojson"

KEEP_PROPS = {"confident", "first_obs_date", "last_obs_date", "scr5_obs_date", "created_at"}

# %%
def date_priority(date_str):
    """
    Compute a priority score from the observation date.

    Alerts closer to CURRENT_DATE receive higher priority. The score is
    calculated as (2600 - days difference) and clipped at 0, so more recent
    observations are prioritized when Tippecanoe needs to drop features.
    Missing or invalid dates return priority = 0.
    """
    
    if not date_str:
        return 0
    
    try:
        d = datetime.strptime(date_str, "%Y-%m-%d").date()
        delta = abs((CURRENT_DATE - d).days)
        return max(0, 2600 - delta)
    
    except ValueError:
        return 0

# %% [markdown]
# ### Create GeoJSON from the CSV

# %%
# Read data
df = pd.read_csv('alerts_20260309.csv')

# Create geodataframe
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))
gdf.crs = 'EPSG:4326'

# Save as geojson file
gdf.to_file('alerts_data.geojson', driver='GeoJSON')

# %% [markdown]
# ### Preprocess the GeoJSON
#
# This cell loads the dataset, keeps only needed fields, and adds the priority score.

# %%
with open(INPUT) as f:
    data = json.load(f)

out_features = []

for feat in data["features"]:
    props = feat["properties"]

    new_props = {k: props[k] for k in KEEP_PROPS if k in props}
    new_props["priority"] = date_priority(props.get("scr5_obs_date"))

    out_features.append({
        "type": "Feature",
        "properties": new_props,
        "geometry": feat["geometry"],
    })

out = {
    "type": "FeatureCollection",
    "features": out_features
}

with open(OUTPUT, "w") as f:
    json.dump(out, f)

print(f"Done. {len(out_features):,} features written to {OUTPUT}")

# %% [markdown]
# ### Generate MBTiles
#
# This cell runs Tippecanoe to create an `.mbtiles` file directly from the notebook.
#
# - The resulting tileset needs to be uploaded to Mapbox.
# - When updating this layer, the Mapbox layer ID must be updated in the frontend to reflect the new upload.

# %%
# !tippecanoe \
  -o alerts_tiles.mbtiles \
  --force \
  -zg \
  --extend-zooms-if-still-dropping \
  --drop-densest-as-needed \
  --drop-rate=1 \
  --order-by=priority \
  --maximum-tile-bytes=500000 \
  --no-feature-limit \
  -l alerts \
  alerts_preprocessed.geojson
