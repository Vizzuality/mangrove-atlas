# %% [markdown]
# # International status widget
#
# Data model for the International Status widget:
#
# {
# id [int],
# Location_id [str] location_id from location table
# indicator [str] one of (nationally_determined_contributions, forest_reference_emissions_levels, ipcc_wetlands_supplement)
# value [str] with the full phrase to display
# }
#
# Each of the phrases are constructed based on the logic explained.

# %%
import pandas as pd
import numpy as np

# %%
policy_data = pd.read_csv('../../../data/Climate_Policy_Data.csv')
column_names = {'NDC Target (mtCO2e/yr)':'ndc_target', 'NDC % Reduction Target':'pct_ndc_target',
       'NDC Target URL':'url', 'NDC Blurb':'blurb', 'Climate Vulnerability Rank (index)':'climate_vulnerability_rank',
       'NDC: first/updated':'ndc_updates', "NDC:includes/doesn't include":'ndc_inclusive',
       'NDC Mitigation (Y/N)':'ndc_mitigation', 'NDC Adaptation (Y/N)':'ndc_adaptation', 'FREL':'frel',
       'Forest or Wetland':'forest_wetland', 'Wetland Supplement':'wetland_suplement'}
policy_data.rename(columns=column_names, inplace=True)
policy_data['frel'] = np.float64(policy_data['frel'])
policy_data['forest_wetland'] = policy_data['forest_wetland'].str.lower()
policy_data.head()
# Out:
#    iso               name  pct_ndc_target  ndc_target  \
# 0  AGO             Angola            50.0       96.65
# 1  ATG  Antigua & Barbuda             NaN         NaN
# 2  AUS          Australia            28.0      161.00
# 3  BHR            Bahrain             NaN         NaN
# 4  BGD         Bangladesh            15.0       35.10
#
#                                                  url  \
# 0  https://www4.unfccc.int/sites/NDCStaging/pages...
# 1  https://www4.unfccc.int/sites/NDCStaging/pages...
# 2  https://www4.unfccc.int/sites/NDCStaging/pages...
# 3  https://www4.unfccc.int/sites/NDCStaging/pages...
# 4  https://www4.unfccc.int/sites/NDCStaging/pages...
#
#                                                blurb  \
# 0  "Angola plans to reduce GHG emissions up to 35...
# 1  Conditional Adaptation Targets " (1) By 2025, ...
# 2  "Under a Paris Agreement applicable to all, Au...
# 3  The Kingdom of Bahrain communicated in its NDC...
# 4  "The NDC of Bangladesh consists of the followi...
#
#    climate_vulnerability_rank ndc_updates    ndc_inclusive ndc_mitigation  \
# 0                      106.67     Updated         Includes             No
# 1                       74.50         NaN  Doesn't include             No
# 2                       52.00     Updated         Includes            Yes
# 3                      125.00         NaN  Doesn't include             No
# 4                       25.00         NaN  Doesn't include             No
#
#   ndc_adaptation      frel forest_wetland wetland_suplement
# 0            Yes       NaN            NaN           Has not
# 1             No       NaN            NaN           Has not
# 2             No       NaN  not specified               Has
# 3             No       NaN            NaN           Has not
# 4             No  374253.0            NaN           Has not

# %% [markdown]
# ## Nationally determined contributions (NDC)
#
# For each country, example sentence:
# `Indonesia` NDC target is `1,181.21` mt CO₂e/yr by 2030.
# Country's `updated/first` NDC `includes/doesn’t include` coastal and marine NBS for `both mitigation and adaptation/mitigation only/adaptation only`
#
# Logic:
# 1. Country name and NDC target are provided in the data.
# 2. If **ndc_updates** = *Updated* --> "updated". Else, "first"
# 3. If **ndc_inclusive** = *Doesn't include* or empty, "Doesn't include...".
# 4. If **ndc_inclusive** = *Includes*, check combintion (yes/no) in **ndc_mitigation** and **ndc_adaptation**

# %%
#ndc = policy_data[['iso','name','ndc_target', 'ndc_updates','ndc_inclusive','ndc_mitigation','ndc_adaptation']].copy()
ndc = policy_data[['iso','name']].copy()
ndc.head()
# Out:
#    iso               name
# 0  AGO             Angola
# 1  ATG  Antigua & Barbuda
# 2  AUS          Australia
# 3  BHR            Bahrain
# 4  BGD         Bangladesh

# %%
no_commitment_phrase = 'has no NDC commitment'

ndc['NDC_target'] = np.where(policy_data['ndc_target'].isna(), no_commitment_phrase, policy_data['ndc_target'])
ndc['NDC_update'] = np.where(policy_data['ndc_target'].isna(), np.nan, np.where(policy_data['ndc_updates'] == 'Updated', 'updated NDC', 'first NDC'))

def ndc_incl(df):
    if((df['ndc_mitigation'] == 'Yes') & (df['ndc_mitigation'] == 'Yes')):
        return('includes coastal and marine NBS for both mitigation and adaptation')
    elif((df['ndc_mitigation'] == 'Yes') & (df['ndc_mitigation'] == 'No')):
        return('includes coastal and marine NBS for mitigation')
    elif((df['ndc_mitigation'] == 'No') & (df['ndc_mitigation'] == 'Yes')):
        return('includes coastal and marine NBS for adaptation')
    else:
        return('doesn\'t include coastal and marine NBS')

ndc['NDC_include'] = policy_data.apply(ndc_incl, axis=1)


def phrase_ndc(df):
    if(df['NDC_target'] == no_commitment_phrase):
        return f'{df["name"]} {no_commitment_phrase}'
    else:
        return f'{df["name"]} NDC target is {df["NDC_target"]} mtCO2e/yr by 2030. This country\'s {df["NDC_update"]} {df["NDC_include"]}'


ndc['value'] = ndc.apply(phrase_ndc, axis=1)
ndc.drop(columns=['NDC_target','NDC_update','NDC_include'], inplace=True)
ndc['indicator'] = 'nationally_determined_contributions'

ndc
# Out:
#      iso                     name  \
# 0    AGO                   Angola
# 1    ATG        Antigua & Barbuda
# 2    AUS                Australia
# 3    BHR                  Bahrain
# 4    BGD               Bangladesh
# ..   ...                      ...
# 96   VUT                  Vanuatu
# 97   VEN                Venezuela
# 98   VNM                  Vietnam
# 99   VGB  Virgin Islands, British
# 100  YEM                    Yemen
#
#                                                  value  \
# 0    Angola NDC target is 96.65 mtCO2e/yr by 2030. ...
# 1              Antigua & Barbuda has no NDC commitment
# 2    Australia NDC target is 161.0 mtCO2e/yr by 203...
# 3                        Bahrain has no NDC commitment
# 4    Bangladesh NDC target is 35.1 mtCO2e/yr by 203...
# ..                                                 ...
# 96   Vanuatu NDC target is 0.07 mtCO2e/yr by 2030. ...
# 97   Venezuela NDC target is 68.0 mtCO2e/yr by 2030...
# 98   Vietnam NDC target is 196.85 mtCO2e/yr by 2030...
# 99       Virgin Islands, British has no NDC commitment
# 100  Yemen NDC target is 6.13 mtCO2e/yr by 2030. Th...
#
#                                indicator
# 0    nationally_determined_contributions
# 1    nationally_determined_contributions
# 2    nationally_determined_contributions
# 3    nationally_determined_contributions
# 4    nationally_determined_contributions
# ..                                   ...
# 96   nationally_determined_contributions
# 97   nationally_determined_contributions
# 98   nationally_determined_contributions
# 99   nationally_determined_contributions
# 100  nationally_determined_contributions
#
# [101 rows x 4 columns]

# %%
country = 'Indonesia'
ndc[ndc['name'] == country]
# Out:
#     iso       name                                              value  \
# 40  IDN  Indonesia  Indonesia NDC target is 1181.21 mtCO2e/yr by 2...
#
#                               indicator
# 40  nationally_determined_contributions

# %% [markdown]
# ## Forest Reference Emission Levels (FRELs)
#
# Sentence:
# `Indonesia` 2017 FREL is `48.9` Mt CO₂e/yr (Indonesia’s mangroves are considered `Forest/Wetland`
#
# Logic:
# 1. FREL value is provided
# 2. forest or wtland consideration is included in the **forest_wetland** field

# %%
country = 'Indonesia'
policy_data[policy_data['name'] == country]['frel']
# Out:
# 40    593329235.0
# Name: frel, dtype: float64

# %%
frel = policy_data[['iso','name']].copy()

def frel_sentence(df):
    if(df['frel'] > 0):
        if(df['forest_wetland'] == 'forest'):
            is_forest = f' (This country\'s mangroves are considered forest).'
        else:
            is_forest = ''
        
        return f'{df["name"]} 2017 FREL is {round(np.int64(df["frel"])/1000000, 2)} Mt CO₂e/yr.{is_forest}'
    else:
        return '-'

frel['value'] = policy_data.apply(frel_sentence, axis = 1)
frel['indicator'] = 'forest_reference_emissions_levels'
frel.head(15)
# Out:
#     iso                           name  \
# 0   AGO                         Angola
# 1   ATG              Antigua & Barbuda
# 2   AUS                      Australia
# 3   BHR                        Bahrain
# 4   BGD                     Bangladesh
# 5   BLZ                         Belize
# 6   BEN                          Benin
# 7   BES  Bonaire, Sint-Eustasius, Saba
# 8   BRA                         Brazil
# 9   BRN                         Brunei
# 10  KHM                       Cambodia
# 11  CMR                       Cameroon
# 12  CYM                     Cayman Is.
# 13  CHN                          China
# 14  COL                       Colombia
#
#                                                 value  \
# 0                                                   -
# 1                                                   -
# 2                                                   -
# 3                                                   -
# 4            Bangladesh 2017 FREL is 0.37 Mt CO₂e/yr.
# 5                Belize 2017 FREL is 5.58 Mt CO₂e/yr.
# 6                                                   -
# 7                                                   -
# 8   Brazil 2017 FREL is 751.78 Mt CO₂e/yr. (This c...
# 9                                                   -
# 10  Cambodia 2017 FREL is 78.95 Mt CO₂e/yr. (This ...
# 11                                                  -
# 12                                                  -
# 13                                                  -
# 14  Colombia 2017 FREL is 51.6 Mt CO₂e/yr. (This c...
#
#                             indicator
# 0   forest_reference_emissions_levels
# 1   forest_reference_emissions_levels
# 2   forest_reference_emissions_levels
# 3   forest_reference_emissions_levels
# 4   forest_reference_emissions_levels
# 5   forest_reference_emissions_levels
# 6   forest_reference_emissions_levels
# 7   forest_reference_emissions_levels
# 8   forest_reference_emissions_levels
# 9   forest_reference_emissions_levels
# 10  forest_reference_emissions_levels
# 11  forest_reference_emissions_levels
# 12  forest_reference_emissions_levels
# 13  forest_reference_emissions_levels
# 14  forest_reference_emissions_levels

# %% [markdown]
# ## Wetands supplement
#
# Sentence:
# Indonesia `has/has not` implemented the Wetlands Supplement
#
# Logic:
# The value is supplied in the field **wetland_suplement**

# %%
wetland = policy_data[['iso','name']].copy()

def wetland_sentence(df):
    return f'{df["name"]} {df["wetland_suplement"].lower()} implemented the Wetlands Supplement'

wetland['indicator'] = 'ipcc_wetlands_supplement'
wetland['value'] = policy_data.apply(wetland_sentence, axis= 1)
wetland.head(15)
# Out:
#     iso                           name                 indicator  \
# 0   AGO                         Angola  ipcc_wetlands_supplement
# 1   ATG              Antigua & Barbuda  ipcc_wetlands_supplement
# 2   AUS                      Australia  ipcc_wetlands_supplement
# 3   BHR                        Bahrain  ipcc_wetlands_supplement
# 4   BGD                     Bangladesh  ipcc_wetlands_supplement
# 5   BLZ                         Belize  ipcc_wetlands_supplement
# 6   BEN                          Benin  ipcc_wetlands_supplement
# 7   BES  Bonaire, Sint-Eustasius, Saba  ipcc_wetlands_supplement
# 8   BRA                         Brazil  ipcc_wetlands_supplement
# 9   BRN                         Brunei  ipcc_wetlands_supplement
# 10  KHM                       Cambodia  ipcc_wetlands_supplement
# 11  CMR                       Cameroon  ipcc_wetlands_supplement
# 12  CYM                     Cayman Is.  ipcc_wetlands_supplement
# 13  CHN                          China  ipcc_wetlands_supplement
# 14  COL                       Colombia  ipcc_wetlands_supplement
#
#                                                 value
# 0   Angola has not implemented the Wetlands Supple...
# 1   Antigua & Barbuda has not implemented the Wetl...
# 2   Australia has implemented the Wetlands Supplement
# 3   Bahrain has not implemented the Wetlands Suppl...
# 4   Bangladesh has not implemented the Wetlands Su...
# 5   Belize has not implemented the Wetlands Supple...
# 6   Benin has not implemented the Wetlands Supplement
# 7   Bonaire, Sint-Eustasius, Saba has not implemen...
# 8   Brazil has not implemented the Wetlands Supple...
# 9   Brunei has not implemented the Wetlands Supple...
# 10  Cambodia has not implemented the Wetlands Supp...
# 11  Cameroon has not implemented the Wetlands Supp...
# 12  Cayman Is. has not implemented the Wetlands Su...
# 13  China has not implemented the Wetlands Supplement
# 14  Colombia has not implemented the Wetlands Supp...

# %% [markdown]
# ## Combine and add location id

# %%
df_combined = pd.concat([ndc, frel, wetland])
df_combined
# Out:
#      iso                     name  \
# 0    AGO                   Angola
# 1    ATG        Antigua & Barbuda
# 2    AUS                Australia
# 3    BHR                  Bahrain
# 4    BGD               Bangladesh
# ..   ...                      ...
# 96   VUT                  Vanuatu
# 97   VEN                Venezuela
# 98   VNM                  Vietnam
# 99   VGB  Virgin Islands, British
# 100  YEM                    Yemen
#
#                                                  value  \
# 0    Angola NDC target is 96.65 mtCO2e/yr by 2030. ...
# 1              Antigua & Barbuda has no NDC commitment
# 2    Australia NDC target is 161.0 mtCO2e/yr by 203...
# 3                        Bahrain has no NDC commitment
# 4    Bangladesh NDC target is 35.1 mtCO2e/yr by 203...
# ..                                                 ...
# 96   Vanuatu has not implemented the Wetlands Suppl...
# 97   Venezuela has not implemented the Wetlands Sup...
# 98   Vietnam has not implemented the Wetlands Suppl...
# 99   Virgin Islands, British has not implemented th...
# 100  Yemen has not implemented the Wetlands Supplement
#
#                                indicator
# 0    nationally_determined_contributions
# 1    nationally_determined_contributions
# 2    nationally_determined_contributions
# 3    nationally_determined_contributions
# 4    nationally_determined_contributions
# ..                                   ...
# 96              ipcc_wetlands_supplement
# 97              ipcc_wetlands_supplement
# 98              ipcc_wetlands_supplement
# 99              ipcc_wetlands_supplement
# 100             ipcc_wetlands_supplement
#
# [303 rows x 4 columns]

# %%
# Import locations to get staging ids
locations = pd.read_csv('../../../data/staging_locations.csv')
locations = locations[locations['location_type'] == 'country']
locations = locations[['id', 'name', 'iso']].copy()
locations.rename(columns={'id':'location_id'}, inplace=True)
locations.head()
# Out:
#      location_id                name  iso
# 159         1402  Dominican Republic  DOM
# 160         1401            Colombia  COL
# 161         1400          Congo, DRC  COD
# 162         1399           Australia  AUS
# 163         1398              Angola  AGO

# %%
df_final = pd.merge(df_combined, locations[['location_id','iso']], on='iso', how='left')
df_final = df_final[~df_final['location_id'].isna()]
df_final = df_final[['location_id', 'indicator', 'value']]
df_final
# Out:
#      location_id                            indicator  \
# 0           1398  nationally_determined_contributions
# 1           1370  nationally_determined_contributions
# 2           1399  nationally_determined_contributions
# 3           1374  nationally_determined_contributions
# 4           1373  nationally_determined_contributions
# ..           ...                                  ...
# 298         1394             ipcc_wetlands_supplement
# 299         1362             ipcc_wetlands_supplement
# 300         1364             ipcc_wetlands_supplement
# 301         1363             ipcc_wetlands_supplement
# 302         1366             ipcc_wetlands_supplement
#
#                                                  value
# 0    Angola NDC target is 96.65 mtCO2e/yr by 2030. ...
# 1              Antigua & Barbuda has no NDC commitment
# 2    Australia NDC target is 161.0 mtCO2e/yr by 203...
# 3                        Bahrain has no NDC commitment
# 4    Bangladesh NDC target is 35.1 mtCO2e/yr by 203...
# ..                                                 ...
# 298  Vanuatu has not implemented the Wetlands Suppl...
# 299  Venezuela has not implemented the Wetlands Sup...
# 300  Vietnam has not implemented the Wetlands Suppl...
# 301  Virgin Islands, British has not implemented th...
# 302  Yemen has not implemented the Wetlands Supplement
#
# [303 rows x 3 columns]

# %%
df_final.to_csv('../../../data/international_status_widget_data.csv', index=False)
